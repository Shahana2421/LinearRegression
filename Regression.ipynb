# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahana2421/LinearRegression/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Salary_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
x=df.iloc[:,:-1]
x
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color="red")
plt.xlabel("Year of Experience")
plt.ylabel("Salary")

plt.plot(x,y,color="g")
plt.show()

# %%
#import seaborn as sns
#sns.regplot(x=df["YearsExperience"],
#y=df["Salary"])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#import seaborn as sns
#sns.regplot(x="YearsExperience",
#y="Salary",data=df)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)
y_predict
# Out:
# array([115791.21011287,  71499.27809463, 102597.86866063,  75268.80422384,
#         55478.79204548,  60190.69970699])

# %%
x_train
# Out:
#     YearsExperience
# 28             10.4
# 24              8.8
# 12              4.1
# 0               1.2
# 4               2.3
# 16              5.2
# 5               3.0
# 13              4.2
# 11              4.1
# 22              8.0
# 1               1.4
# 2               1.6
# 25              9.1
# 3               2.1
# 21              7.2
# 26              9.6
# 18              6.0
# 29             10.6
# 20              6.9
# 7               3.3
# 10              4.0
# 14              4.6
# 19              6.1
# 6               3.1

# %%
x_test.shape
# Out:
# (6, 1)

# %%
x_train.shape
# Out:
# (24, 1)

# %%
y_test.values
# Out:
# array([112636.,  67939., 113813.,  83089.,  64446.,  57190.])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

plt.scatter(x_test,y_predict,color="r")
plt.plot(x_test,y_predict,color="g")
plt.show()

# %%
y_predict=lr.predict([[7]])
y_predict
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([90346.90874069])

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [9423.81532303]
# 24380.201479473704

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.9024461774180497

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_predict)
# Out:
# 49830096.855908394

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_predict)
# Out:
# 6286.453830757745
